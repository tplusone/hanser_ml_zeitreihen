# %% [markdown]
# ### Saisonal-ARIMA zur Schätzung von monatlichen Temperaturdaten

# %% [markdown]
# #### 1) Daten laden

# %%
import pandas as pd
from math import ceil

pd.set_option('display.max_columns', 6)

data_url=r'https://github.com/tplusone/hanser_ml_zeitreihen/blob/master/Daten/jena_climate_temp_monthly.csv?raw=true'
df = pd.read_csv(data_url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-cf1e4105ef8f> in <module>
#       5
#       6 data_url=r'https://github.com/tplusone/hanser_ml_zeitreihen/blob/master/Daten/jena_climate_temp_monthly.csv?raw=true'
# ----> 7 df = pd.read_csv(data_url)
#       8 df.head()
#
# ...
